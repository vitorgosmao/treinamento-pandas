# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': {'X': 1}, 'B': {'X': 2}})
df2 = pd.DataFrame({'C': {'X': 3}, 'D': {'X': 4}})
pd.concat([df1, df2])
# Out:
#      A    B    C    D
# X  1.0  2.0  NaN  NaN
# X  NaN  NaN  3.0  4.0

# %%
dados = [('A', 'B'), ('C', 'D')]
df = pd.DataFrame(dados, columns = ['L1', 'L2'],  index = ['C1', 'C2'])
df
# Out:
#    L1 L2
# C1  A  B
# C2  C  D

# %%
dados = [[1, 2, 3], [4, 5, 6]]
index = 'X,Y'.split(',')
columns = list('CBA')[::-1]
df = pd.DataFrame(dados, index, columns)
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6

# %%
dados = {'A': {'X': 1, 'Y': 3}, 'B': {'X': 2, 'Y': 4}}
df = pd.DataFrame(dados)
df
# Out:
#    A  B
# X  1  2
# Y  3  4

# %%
import pandas as pd

numeros = [i for i in range(11)]
letras = [chr(i + 65) for i in range(11)]
nome_coluna = ['N']

df = pd.DataFrame(data = numeros, index = letras, columns = nome_coluna)

# %%
selecao = df['N'].isin([i for i in range(11) if i % 2 == 0])
df = df[selecao]
df
# Out:
#     N
# A   0
# C   2
# E   4
# G   6
# I   8
# K  10

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
selecao = alunos['Aprovado'] == True
aprovados = alunos[selecao]
aprovados
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
selecao = alunos.Aprovado == True & alunos.Sexo == 'F'
aprovadas = alunos[selecao]
aprovadas
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Python39\lib\site-packages\pandas\core\ops\array_ops.py:302, in na_logical_op(x, y, op)
#     293 try:
#     294     # For exposition, write:
#     295     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     300     # Then Cases where this goes through without raising include:
#     301     #  (xint or xbool) and (yint or bool)
# --> 302     result = op(x, y)
#     303 except TypeError:
#
# File C:\Python39\lib\site-packages\pandas\core\roperator.py:52, in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File C:\Python39\lib\site-packages\pandas\core\ops\array_ops.py:316, in na_logical_op(x, y, op)
#     315 try:
# --> 316     result = libops.scalar_binop(x, y, op)
#     317 except (
#     318     TypeError,
#     319     ValueError,
#    (...)
#     322     NotImplementedError,
#     323 ) as err:
#
# File C:\Python39\lib\site-packages\pandas\_libs\ops.pyx:210, in pandas._libs.ops.scalar_binop()
#
# File C:\Python39\lib\site-packages\pandas\core\roperator.py:52, in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 selecao = alunos.Aprovado == True & alunos.Sexo == 'F'
#       2 aprovadas = alunos[selecao]
#       3 aprovadas
#
# File C:\Python39\lib\site-packages\pandas\core\ops\common.py:69, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      65             return NotImplemented
#      67 other = item_from_zerodim(other)
# ---> 69 return method(self, other)
#
# File C:\Python39\lib\site-packages\pandas\core\arraylike.py:66, in OpsMixin.__rand__(self, other)
#      64 @unpack_zerodim_and_defer("__rand__")
#      65 def __rand__(self, other):
# ---> 66     return self._logical_method(other, roperator.rand_)
#
# File C:\Python39\lib\site-packages\pandas\core\series.py:5513, in Series._logical_method(self, other, op)
#    5510 lvalues = self._values
#    5511 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5513 res_values = ops.logical_op(lvalues, rvalues, op)
#    5514 return self._construct_result(res_values, name=res_name)
#
# File C:\Python39\lib\site-packages\pandas\core\ops\array_ops.py:392, in logical_op(left, right, op)
#     388 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     389 #   integer dtypes.  Otherwise these are boolean ops
#     390 filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# --> 392 res_values = na_logical_op(lvalues, rvalues, op)
#     393 # error: Cannot call function of unknown type
#     394 res_values = filler(res_values)  # type: ignore[operator]
#
# File C:\Python39\lib\site-packages\pandas\core\ops\array_ops.py:325, in na_logical_op(x, y, op)
#     317         except (
#     318             TypeError,
#     319             ValueError,
#    (...)
#     322             NotImplementedError,
#     323         ) as err:
#     324             typ = type(y).__name__
# --> 325             raise TypeError(
#     326                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     327                 f"and scalar of type [{typ}]"
#     328             ) from err
#     330 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'rand_' with a dtyped [object] array and scalar of type [bool]

# %%
selecao = ((alunos.Idade > 10) & 
    (alunos.Idade < 20)) | (alunos.Idade >= 40)
alunos[selecao]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 2   Denis     56    M    5.0     False
# 4   Bruna     42    F    8.2      True
# 6  Carlos     19    M    6.0     False

# %%
selecao = alunos['Aprovado'] == False
reprovados = alunos.iloc[selecao, ['Nome', 'Sexo', 'Idade']]
reprovados
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [68], in <cell line: 2>()
#       1 selecao = alunos['Aprovado'] == False
# ----> 2 reprovados = alunos.iloc[selecao, ['Nome', 'Sexo', 'Idade']]
#       3 reprovados
#
# File C:\Python39\lib\site-packages\pandas\core\indexing.py:925, in _LocationIndexer.__getitem__(self, key)
#     923         with suppress(KeyError, IndexError):
#     924             return self.obj._get_value(*key, takeable=self._takeable)
# --> 925     return self._getitem_tuple(key)
#     926 else:
#     927     # we by definition only have the 0th axis
#     928     axis = self.axis or 0
#
# File C:\Python39\lib\site-packages\pandas\core\indexing.py:1506, in _iLocIndexer._getitem_tuple(self, tup)
#    1504 def _getitem_tuple(self, tup: tuple):
# -> 1506     self._has_valid_tuple(tup)
#    1507     with suppress(IndexingError):
#    1508         return self._getitem_lowerdim(tup)
#
# File C:\Python39\lib\site-packages\pandas\core\indexing.py:754, in _LocationIndexer._has_valid_tuple(self, key)
#     752 for i, k in enumerate(key):
#     753     try:
# --> 754         self._validate_key(k, i)
#     755     except ValueError as err:
#     756         raise ValueError(
#     757             "Location based indexing can only have "
#     758             f"[{self._valid_types}] types"
#     759         ) from err
#
# File C:\Python39\lib\site-packages\pandas\core\indexing.py:1395, in _iLocIndexer._validate_key(self, key, axis)
#    1393 if hasattr(key, "index") and isinstance(key.index, Index):
#    1394     if key.index.inferred_type == "integer":
# -> 1395         raise NotImplementedError(
#    1396             "iLocation based boolean "
#    1397             "indexing on an integer type "
#    1398             "is not available"
#    1399         )
#    1400     raise ValueError(
#    1401         "iLocation based boolean indexing cannot use "
#    1402         "an indexable as a mask"
#    1403     )
#    1404 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
selecao = alunos['Aprovado'] == False
reprovados = alunos[selecao]['Nome', 'Sexo', 'Idade']
reprovados
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python39\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File C:\Python39\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python39\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Nome', 'Sexo', 'Idade')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [69], in <cell line: 2>()
#       1 selecao = alunos['Aprovado'] == False
# ----> 2 reprovados = alunos[selecao]['Nome', 'Sexo', 'Idade']
#       3 reprovados
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File C:\Python39\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: ('Nome', 'Sexo', 'Idade')

# %%
selecao = alunos['Aprovado'] == False
reprovados = alunos[['Nome', 'Sexo', 'Idade']][selecao]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
selecao = alunos['Aprovado'] == False
reprovados = alunos.loc[selecao, ['Nome', 'Sexo', 'Idade']]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
alunos.sort_values(by = ['Idade'], inplace = True)
alunos.iloc[1:3]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True

# %%
alunos.sort_values(by = ['Idade'], inplace = True)
alunos.iloc[3]
# Out:
# Nome        Cátia
# Idade          27
# Sexo            F
# Notas         2.5
# Aprovado    False
# Name: 1, dtype: object

# %%
alunos.sort_values(by = ['Idade'], inplace = True)
alunos.iloc[:3]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True

# %%
imoveis = pd.DataFrame([['Apartamento', None, 970, 68], 
                        ['Apartamento', 2000, 878, 112], 
                        ['Casa', 5000, None, 500], 
                        ['Apartamento', None, 1010, 170], 
                        ['Apartamento', 1500, 850, None], 
                        ['Casa', None, None, None], 
                        ['Apartamento', 2000, 878, None], 
                        ['Apartamento', 1550, None, 228], 
                        ['Apartamento', 2500, 880, 195]], 
                        columns = ['Tipo', 'Valor', 'Condominio', 'IPTU'])

# %%
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento     NaN       970.0   68.0
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 3  Apartamento     NaN      1010.0  170.0
# 4  Apartamento  1500.0       850.0    NaN
# 5         Casa     NaN         NaN    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis.dropna(subset = ['Valor'])
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 4  Apartamento  1500.0       850.0    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
selecao = (imoveis['Tipo'] == 'Apartamento') & (imoveis['Condominio'].isnull())
imoveis[~selecao]
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento  2000.0       878.0  112.0
# 1         Casa  5000.0         NaN  500.0
# 2  Apartamento  1500.0       850.0    NaN
# 3  Apartamento  2000.0       878.0    NaN
# 5  Apartamento  2500.0       880.0  195.0

# %%
imoveis.fillna({'Condominio': 0, 'IPTU': 0})
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         0.0  500.0
# 4  Apartamento  1500.0       850.0    0.0
# 6  Apartamento  2000.0       878.0    0.0
# 7  Apartamento  1550.0         0.0  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis.index = range(imoveis.shape[0])
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento  2000.0       878.0  112.0
# 1         Casa  5000.0         NaN  500.0
# 2  Apartamento  1500.0       850.0    NaN
# 3  Apartamento  2000.0       878.0    NaN
# 4  Apartamento  1550.0         NaN  228.0
# 5  Apartamento  2500.0       880.0  195.0

# %%
atletas = pd.DataFrame([['Marcos', 9.62], ['Pedro', None], ['João', 9.69], 
                        ['Beto', 9.72], ['Sandro', None], ['Denis', 9.69], 
                        ['Ary', None], ['Carlos', 9.74]], 
                        columns = ['Corredor', 'Melhor Tempo'])
atletas
# Out:
#   Corredor  Melhor Tempo
# 0   Marcos          9.62
# 1    Pedro           NaN
# 2     João          9.69
# 3     Beto          9.72
# 4   Sandro           NaN
# 5    Denis          9.69
# 6      Ary           NaN
# 7   Carlos          9.74

# %%
atletas.fillna(mean(), inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 atletas.fillna(mean(), inplace = True)
#
# NameError: name 'mean' is not defined

# %%
atletas.fillna(atletas["Melhor Tempo"].mean(), inplace = True)

# %%
atletas
# Out:
#   Corredor  Melhor Tempo
# 0   Marcos         9.620
# 1    Pedro         9.692
# 2     João         9.690
# 3     Beto         9.720
# 4   Sandro         9.692
# 5    Denis         9.690
# 6      Ary         9.692
# 7   Carlos         9.740

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas'])
alunos
# Out:
#      Nome  Idade Sexo  Notas
# 0     Ary     15    M    7.5
# 1   Cátia     27    F    2.5
# 2   Denis     56    M    5.0
# 3    Beto     32    M   10.0
# 4   Bruna     42    F    8.2
# 5    Dara     21    F    7.0
# 6  Carlos     19    M    6.0
# 7   Alice     35    F    5.6

# %%
alunos['Notas-Média(Notas)'] = 
    alunos.Notas - alunos.Notas.mean()
# Out:
#   Input In [92]
#     alunos['Notas-Média(Notas)'] =
#                                    ^
# SyntaxError: invalid syntax

# %%
m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
eventos = {'m1': m1, 
            'm2': m2, 
            'm3': m3, 
            'm4': m4, 
            'm5': m5}
moedas = pd.DataFrame(eventos)
df = pd.DataFrame(data = ['Cara', 'Coroa'], 
                    index = ['c', 'C'], 
                    columns = ['Faces'])
for item in moedas:
    df = pd.concat([df, moedas[item].value_counts()], 
                    axis = 1)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [94], in <cell line: 6>()
#       1 eventos = {'m1': m1,
#       2             'm2': m2,
#       3             'm3': m3,
#       4             'm4': m4,
#       5             'm5': m5}
# ----> 6 moedas = pd.DataFrame(eventos)
#       7 df = pd.DataFrame(data = ['Cara', 'Coroa'],
#       8                     index = ['c', 'C'],
#       9                     columns = ['Faces'])
#      10 for item in moedas:
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:614, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     608     mgr = self._init_mgr(
#     609         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     610     )
#     612 elif isinstance(data, dict):
#     613     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615 elif isinstance(data, ma.MaskedArray):
#     616     import numpy.ma.mrecords as mrecords
#
# File C:\Python39\lib\site-packages\pandas\core\internals\construction.py:464, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     456     arrays = [
#     457         x
#     458         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     459         else x.copy()
#     460         for x in arrays
#     461     ]
#     462     # TODO: can we get rid of the dt64tz special case above?
# --> 464 return arrays_to_mgr(
#     465     arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466 )
#
# File C:\Python39\lib\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     116 if verify_integrity:
#     117     # figure out the index, if necessary
#     118     if index is None:
# --> 119         index = _extract_index(arrays)
#     120     else:
#     121         index = ensure_index(index)
#
# File C:\Python39\lib\site-packages\pandas\core\internals\construction.py:625, in _extract_index(data)
#     622         raw_lengths.append(len(val))
#     624 if not indexes and not raw_lengths:
# --> 625     raise ValueError("If using all scalar values, you must pass an index")
#     627 if have_series:
#     628     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
eventos = {'m1': list(m1), 
            'm2': list(m2), 
            'm3': list(m3), 
            'm4': list(m4), 
            'm5': list(m5)}
moedas = pd.DataFrame(eventos)
df = pd.DataFrame(data = ['Cara', 'Coroa'], 
                    index = ['c', 'C'], 
                    columns = ['Faces'])
for item in moedas:
    df = pd.concat([df, moedas[item].value_counts()], 
                    axis = 1)
df
# Out:
#    Faces  m1  m2  m3  m4  m5
# c   Cara  25  26  19  23  25
# C  Coroa  25  24  31  27  25

# %%
eventos = {'m1': list(m1), 
            'm2': list(m2), 
            'm3': list(m3), 
            'm4': list(m4), 
            'm5': list(m5)}
moedas = pd.DataFrame(eventos)
df = pd.DataFrame(data = ['Cara', 'Coroa'], 
                    index = ['c', 'C'], 
                    columns = ['Faces'])
for item in moedas:
    df = pd.concat([df, moedas[item].sum()], 
                    axis = 1)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [96], in <cell line: 10>()
#       7 df = pd.DataFrame(data = ['Cara', 'Coroa'],
#       8                     index = ['c', 'C'],
#       9                     columns = ['Faces'])
#      10 for item in moedas:
# ---> 11     df = pd.concat([df, moedas[item].sum()],
#      12                     axis = 1)
#      13 df
#
# File C:\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python39\lib\site-packages\pandas\core\reshape\concat.py:294, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#      90 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#      91 def concat(
#      92     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     101     copy: bool = True,
#     102 ) -> FrameOrSeriesUnion:
#     103     """
#     104     Concatenate pandas objects along a particular axis with optional set logic
#     105     along the other axes.
#    (...)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#     297         ignore_index=ignore_index,
#     298         join=join,
#     299         keys=keys,
#     300         levels=levels,
#     301         names=names,
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
#     304         sort=sort,
#     305     )
#     307     return op.get_result()
#
# File C:\Python39\lib\site-packages\pandas\core\reshape\concat.py:384, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     379     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     380         msg = (
#     381             f"cannot concatenate object of type '{type(obj)}'; "
#     382             "only Series and DataFrame objs are valid"
#     383         )
# --> 384         raise TypeError(msg)
#     386     ndims.add(obj.ndim)
#     388 # get the sample
#     389 # want the highest ndim that we have, and must be non-empty
#     390 # unless all objs are empty
#
# TypeError: cannot concatenate object of type '<class 'str'>'; only Series and DataFrame objs are valid

# %%
eventos = {'m1': list(m1), 
            'm2': list(m2), 
            'm3': list(m3), 
            'm4': list(m4), 
            'm5': list(m5)}
moedas = pd.DataFrame(eventos)
for item in moedas:
    df = pd.concat([df, moedas[item].value_counts()], 
                    axis = 1)
df
# Out:
#    Faces  m1  m2  m3  m4  m5
# c   Cara  25  26  19  23  25
# C  Coroa  25  24  31  27  25

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
sexo = alunos.groupby()
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [100], in <cell line: 1>()
# ----> 1 sexo = alunos.groupby()
#       2 sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
#       3 sexo.columns = ['Notas Médias']
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:7626, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7623     squeeze = False
#    7625 if level is None and by is None:
# -> 7626     raise TypeError("You have to supply one of 'by' and 'level'")
#    7627 axis = self._get_axis_number(axis)
#    7629 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630 # "Union[bool, NoDefault]"; expected "bool"
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto')
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão','min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes)
# Out:
#             Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Batata   3.960000       0.256320    3.69     4.2
# Cebola   2.060000       0.409512    1.69     2.5
# Tomate   3.426667       0.518684    2.99     4.0

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão','min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Batata    3.96           0.26    3.69     4.2
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
